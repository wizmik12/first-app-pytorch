# %% [markdown]
# # Generative networks
#
# Recurrent Neural Networks (RNNs) and their gated cell variants such as Long Short Term Memory Cells (LSTMs) and Gated Recurrent Units (GRUs) provided a mechanism for language modeling, i.e. they can learn word ordering and provide predictions for next word in a sequence. This allows us to use RNNs for **generative tasks**, such as ordinary text generation, machine translation, and even image captioning.
#
# In RNN architecture we discussed in the previous unit, each RNN unit produced next next hidden state as an output. However, we can also add another output to each recurrent unit, which would allow us to output a **sequence** (which is equal in length to the original sequence). Moreover, we can use RNN units that do not accept an input at each step, and just take some initial state vector, and then produce a sequence of outputs.
#
# This allows for different neural architectures that are shown in the picture below:
#
# <img alt="Image showing common recurrent neural network patterns." src="images/6-generative-networks-1.jpg" align="middle" />
# *Image from blog post "Unreasonable Effectiveness of Recurrent Neural Networks" by Andrej Karpaty*
#
# * **One-to-one** is a traditional neural network with one input and one output
# * **One-to-many** is a generative architecture that accepts one input value, and generates a sequence of output values. For example, if we want to train `image captioning` network that would produce a textual description of a picture, we can have a picture as input, pass it through CNN to obtain hidden state, and then have recurrent chain generate caption word-by-word
# * **Many-to-one** corresponds to RNN architectures we described in the previous unit, such as `text classification`
# * **Many-to-many**, or **sequence-to-sequence** corresponds to tasks such as `machine translation` or `language translation`, where we have first RNN collect all information from the input sequence into the hidden state, and another RNN chain unrolls this state into the output sequence.
#
# In this unit, we will focus on simple *generative models* that help us generate text. For simplicity, let's build a **character-level network**, which generates news articles text letter by letter. While generating news articles may seem quite impractical, the same idea of sequence generation is used in many practical tasks, such as machine translation, text summarization, etc.
#
# During training, we need to take some text corpus, and split it into letter sequences.

# %%
import torch
import torchtext
import numpy as np
from torchnlp import *
from collections import Counter

train_dataset, test_dataset = torchtext.datasets.AG_NEWS(root='../data')
classes = ['World', 'Sports', 'Business', 'Sci/Tech']
tokenizer = torchtext.data.utils.get_tokenizer('basic_english')
counter = Counter()
for (label, line) in train_dataset:
    counter.update(tokenizer(line))
vocab_= torchtext.vocab.vocab(counter)

vocab_size = len(vocab_)

# %%
vocab_.get_stoi()
# Out:
# {'43-27-3': 95809,
#  'wind-affected': 95808,
#  'interrogating': 95804,
#  'key\\positions': 95801,
#  'quit\\lebanon': 95800,
#  'northern\\export': 95794,
#  'the\\busiest': 95791,
#  'mega-deals': 95790,
#  'week\\with': 95788,
#  'glue-fingered': 95785,
#  'triplex': 95783,
#  'dancerella': 95782,
#  '165-year-old': 95780,
#  'googleizing': 95778,
#  'kidsgrove': 95772,
#  '564': 95771,
#  'indoctrinated': 95769,
#  '97-88': 95768,
#  'by\\telling': 95765,
#  'down\\expectations': 95763,
#  'tarver-glen': 95760,
#  '10-19': 95752,
#  'hysterical': 95747,
#  'lilliputians': 95745,
#  'nots': 95744,
#  'mashrafe': 95742,
#  '120-116': 95739,
#  'pain-reliever': 95736,
#  'jimerson': 95734,
#  'chatty': 95733,
#  'capt': 95730,
#  'dengue': 95729,
#  'jmu': 95727,
#  '89-to-84': 95722,
#  'torturers': 95721,
#  'occupuing': 95719,
#  'so-funny': 95716,
#  'multi-team': 95715,
#  'imap4': 95713,
#  'gsm/gprs/edge': 95712,
#  'madsen': 95710,
#  '273/7': 95708,
#  '114-106': 95705,
#  'run-and-gun': 95698,
#  'hps': 95697,
#  'mainproduction': 95695,
#  '\\$425m': 95693,
#  'three-storey': 95692,
#  'free\\\\': 95689,
#  '\\\\\\': 95686,
#  'and\\elevating': 95682,
#  'launched\\its': 95680,
#  '89-86': 95678,
#  'fromthe': 95677,
#  'hand-lettered': 95675,
#  'annexing': 95673,
#  'codeand': 95671,
#  'comes\\just': 95667,
#  'heart\\attack': 95666,
#  'popular\\celebrex': 95665,
#  'bubin': 95664,
#  'three-level': 95663,
#  '8-and-4': 95658,
#  '-nur': 95657,
#  'him\\a': 95655,
#  '2-investment': 95653,
#  'incites': 95646,
#  'easier-to-crawl': 95643,
#  'sorrows': 95641,
#  'demjanjuk': 95637,
#  'customer-relations': 95631,
#  'jonkoping': 95627,
#  'stagg': 95624,
#  'solicits': 95621,
#  'double-dipping': 95616,
#  'guarino': 95614,
#  'anti-regime': 95613,
#  '422-155': 95612,
#  '321-115': 95610,
#  '197-53': 95609,
#  'ronaldinhos': 95607,
#  'numerology': 95606,
#  'kyis': 95605,
#  'satursday': 95604,
#  'newton-based': 95603,
#  'comed': 95599,
#  'cyberextortion': 95598,
#  'must\\slash': 95596,
#  'moolah': 95594,
#  '415m': 95589,
#  'corporate-sponsored': 95582,
#  'center/forward': 95579,
#  'optimization\\\\i': 95573,
#  'us\\$350': 95566,
#  'villacis': 95565,
#  'nandrolone': 95562,
#  'knauss': 95561,
#  'throughout\\the': 95559,
#  'season\\because': 95558,
#  'forth-generation': 95557,
#  'gnarly': 95555,
#  'franchising': 95554,
#  'hpt': 95553,
#  'ihg': 95551,
#  'leverkuzen': 95549,
#  'tourist\\attractions': 95547,
#  'forcing\\officials': 95546,
#  'northern\\and': 95545,
#  'a\\panel': 95544,
#  'sean\\o': 95542,
#  'sony-ericsson': 95540,
#  'wyclef': 95539,
#  'roethlisbergers': 95536,
#  'receptivity': 95533,
#  'gothamites': 95530,
#  'assumpcao&lt': 95525,
#  'year\\without': 95523,
#  'face\\an': 95521,
#  'are\\unpopular': 95520,
#  'five-times': 95516,
#  'using\\chemicals': 95515,
#  'authorities\\are': 95508,
#  'icarus': 95507,
#  'apol': 95506,
#  'mysql-certified': 95504,
#  'still-solid': 95503,
#  'anti-monarchy': 95502,
#  'dosages': 95498,
#  'underpromising': 95496,
#  'haryana': 95494,
#  'jharkhand': 95493,
#  'confoundedly': 95491,
#  'ticker=bhi': 95489,
#  'alfonseca': 95487,
#  'mikerevic': 95484,
#  'bakhshi': 95482,
#  'salam': 95481,
#  'priolo': 95478,
#  'rivalry-esque': 95476,
#  'jaundice': 95475,
#  'of-mutual-interest': 95473,
#  'spy-bug': 95472,
#  'berlin/london': 95466,
#  'key\\products': 95465,
#  'and\\eli': 95464,
#  'dealt\\a': 95462,
#  'last-16': 95461,
#  'qos': 95459,
#  'with\\jaundice': 95455,
#  'strutted': 95448,
#  '20-digit': 95447,
#  'sales\\\\apple': 95446,
#  'opining': 95444,
#  'transact': 95439,
#  'air-bag': 95437,
#  'harney': 95434,
#  'anti-dumpinglaw': 95432,
#  'hitthe': 95431,
#  'memberof': 95430,
#  'aviator/billionaire/loony': 95425,
#  'vaporware': 95424,
#  'defense-in-depth': 95421,
#  'mayzel': 95418,
#  'reviews\\\\almost': 95416,
#  'content\\\\yahoo': 95415,
#  'essays': 95414,
#  'sulfurous': 95412,
#  'kaen': 95408,
#  'non-fatal': 95404,
#  'crochet': 95401,
#  'sources\\and': 95399,
#  'toward\\closer': 95397,
#  'ivanic': 95395,
#  'mladen': 95394,
#  'aeuronautics': 95390,
#  'us\\$415': 95388,
#  'toy-making': 95385,
#  'stipulates': 95383,
#  '000-1': 95379,
#  'cess': 95378,
#  'genre-busters': 95374,
#  '100tb': 95372,
#  '4g': 95370,
#  'military\\offensive': 95366,
#  'ammunition\\have': 95365,
#  'cross-breed': 95361,
#  'asit': 95360,
#  'indiagames': 95356,
#  'jabba': 95353,
#  'life-sized': 95352,
#  'a\\moderate': 95350,
#  'secession': 95347,
#  'anti-secession': 95346,
#  'anti-scalping': 95344,
#  'at\\ending': 95342,
#  'korea\\jointly': 95341,
#  'ahmoud': 95337,
#  '4-pakistan': 95336,
#  'ticker=osip': 95335,
#  'group\\yukos': 95334,
#  'improved\\distribution': 95332,
#  'week&lt': 95325,
#  'flaws&lt': 95324,
#  '\\$44m': 95317,
#  'kingsway': 95315,
#  'over-ambition': 95310,
#  'rijkman': 95308,
#  'candour': 95307,
#  'family-appointed': 95304,
#  '15-0': 95303,
#  'martinezs': 95302,
#  'training-camp': 95301,
#  'airballs': 95300,
#  'newsflow': 95297,
#  'lott': 95293,
#  'crosschecker': 95290,
#  'sawdaye': 95289,
#  '6-point': 95287,
#  'sho': 95286,
#  '99-loss': 95725,
#  'ynez': 95285,
#  'ebo': 95284,
#  'learners': 95281,
#  'bilodeau': 95280,
#  'manny-style': 95274,
#  'world\\body': 95273,
#  'two\\prisoners': 95262,
#  'jailbreak': 95261,
#  'sexual-dysfunction': 95260,
#  'breast-enlargement': 95259,
#  'lumpur-based': 95256,
#  'cardiologist': 95252,
#  'ex-pennichuck': 95250,
#  'juggernauts': 95249,
#  'joe-4-wind': 95247,
#  'iressa\\failed': 95452,
#  'sampler': 95245,
#  'schoolfriends': 95243,
#  'almost\\two': 95240,
#  'rural\\immigration': 95239,
#  'australian\\political': 95237,
#  'ticking-off': 95236,
#  'to\\block': 95235,
#  'company\\yukos': 95234,
#  'softwarehas': 95233,
#  '115-99': 95230,
#  'while\\i': 95227,
#  'images\\within': 95226,
#  'for\\associating': 95225,
#  'foaf': 95224,
#  'denote': 95221,
#  '\\\\using': 95220,
#  'percent\\after': 95218,
#  '754': 95215,
#  'state-imposed': 95214,
#  'decision\\to': 95213,
#  'major\\yukos': 95212,
#  'hardin-baylor': 95209,
#  'conradt': 95208,
#  'sleeplessness': 95206,
#  'the\\cleveland': 95200,
#  'inpex': 95197,
#  '1p': 95196,
#  'sensor-based': 95192,
#  '81-69': 95187,
#  'di-ve': 95185,
#  '442bn': 95184,
#  'vetoing': 95182,
#  'blackberry-enabled': 95180,
#  'palestinian\\presidential': 95174,
#  'afresh': 95171,
#  'beijing\\on': 95170,
#  'defected\\from': 95169,
#  'shifty': 95168,
#  'undiscovered': 95162,
#  'bickerton': 95161,
#  'ex-nebraska': 95156,
#  'carmignani': 95152,
#  'estwithin': 95147,
#  'chin-music': 95145,
#  'reoffend': 95139,
#  'ira-style': 95137,
#  'jeddah/riyadh': 95136,
#  'sledging': 95135,
#  'inflame': 95131,
#  'miffs': 95129,
#  'grealy': 95128,
#  'management-consulting': 95126,
#  'ticker=ttwo': 95125,
#  'ira-linked': 95124,
#  '1940': 95122,
#  'katyn': 95121,
#  'four-cylinder': 95118,
#  'from\\production': 95117,
#  'in\\2012': 95115,
#  'the\\heavyweight': 95113,
#  'market-leading\\itunes': 95112,
#  'non-junta': 95111,
#  'v6': 95103,
#  'vacillated': 95100,
#  'incisive': 95094,
#  'akhtars': 95093,
#  'gartneranalysts': 95089,
#  'deal-breaking': 95088,
#  'hodgkins': 95082,
#  'cutesy': 95080,
#  'symantec/veritas': 95074,
#  'and\\converse': 95073,
#  'concerns-survey': 95072,
#  'high-stress': 95070,
#  'ticker=hnkg': 95068,
#  'incriminated': 95067,
#  'macaca': 95059,
#  'iden': 95058,
#  'ex-dolphins': 95054,
#  'petrel': 95047,
#  '78-5': 95046,
#  'spitballs': 95041,
#  'dowsa': 95037,
#  'darfuri': 95036,
#  'manufacturing\\goods': 95035,
#  'of\\violence': 95032,
#  'donvand': 95023,
#  'state-sharon': 95018,
#  '1-million-plus': 95017,
#  'low-brand': 95015,
#  'salvatore': 95013,
#  'c-117': 95010,
#  'patina': 95003,
#  'a\\classic': 95000,
#  'to\\indebtedness': 94998,
#  'the\\story': 94995,
#  '1-levi\\strauss': 94994,
#  'with\\driving': 94993,
#  'punter\\todd': 94992,
#  '1850km': 94991,
#  'napping': 94987,
#  'ayoob': 94986,
#  'psps': 94985,
#  'macaque': 94984,
#  'dtsearch': 94983,
#  'enfish': 94982,
#  'dolomites': 94978,
#  '\\deputy': 94975,
#  'quarter-billion': 94974,
#  '1-goldman': 94973,
#  'ticker=ccl': 94972,
#  'powderfinger': 94965,
#  'glamis': 94953,
#  'ciampi': 94952,
#  'unknowability': 94950,
#  'euro820': 94947,
#  'third\\quarter': 94945,
#  'deficit\\widened': 94944,
#  'shannan': 94943,
#  'senior\\organizer': 94940,
#  'to\\allow': 94939,
#  'enron-sized': 94936,
#  'ex-taiwan': 94934,
#  'geoscientists': 94932,
#  'implantible': 94929,
#  'its\\current': 94928,
#  'army-to-army': 94925,
#  'ex-champion': 94924,
#  '16th-round': 94923,
#  'warriors-': 94922,
#  '\\expanding': 94919,
#  'moglia': 94918,
#  '950m': 94916,
#  'wickes': 94915,
#  'ralphs': 94913,
#  '118-year': 94911,
#  '357': 94909,
#  'arunachal': 94907,
#  'single-c': 94903,
#  'unattainable': 94902,
#  'charge-coupled': 94900,
#  'activehome': 94894,
#  'x10': 94893,
#  'hertzfeld': 94892,
#  'decends': 94891,
#  'tas': 94890,
#  '\\getting': 94885,
#  'equipped\\for': 94884,
#  'roaming-capable': 94882,
#  'government-ordered': 94881,
#  'water-damage': 94878,
#  'bedritsky': 94875,
#  'powder-puff': 94872,
#  'mccoist': 94871,
#  '26mb': 94869,
#  'most\\frequently': 94859,
#  'hearkening': 94850,
#  'stock-and-cash': 94849,
#  'draft-day': 94847,
#  'shanika': 94846,
#  '220-5': 94839,
#  'six-player': 94837,
#  'become\\key': 94836,
#  'the\\dutch': 94834,
#  '12million': 94831,
#  'relativism': 94830,
#  '30-18': 94828,
#  'clausen': 94827,
#  'serono': 94823,
#  'stn/cstn-lcd': 94821,
#  'cstn': 94819,
#  'alcohol-related': 94815,
#  'berkowitz': 94813,
#  'sudbury': 94811,
#  '--japan': 94810,
#  'r-redlands': 94801,
#  'tuffey': 94799,
#  'muffin': 94798,
#  'mccourt': 94796,
#  'entryway': 94791,
#  'arrestedafter': 94788,
#  'be\\able': 94785,
#  '-laf': 94778,
#  'communications\\inc': 94776,
#  'mobilemusic': 94775,
#  'rpp': 94773,
#  '72-47': 94771,
#  'between\\israel': 94769,
#  'gassing': 94766,
#  'front\\in': 94764,
#  'highest\\level': 94763,
#  'implantable\\devices': 94762,
#  'fast-selling': 94761,
#  'victory-starved': 94759,
#  'otaku': 94756,
#  'f9': 94754,
#  '750k': 94751,
#  'begala': 94748,
#  'intelliseek': 94746,
#  'louisianna-lafayette': 94740,
#  'servicebuilder': 94739,
#  'communicationstook': 94736,
#  'sprintand': 94735,
#  '30-person': 94734,
#  'katana': 94733,
#  'manassas': 94729,
#  'turboprop': 94727,
#  'animals\\scrounging': 94725,
#  'a\\heart': 94723,
#  'the\\first-ever': 94721,
#  'software\\business': 94720,
#  'local-level': 94719,
#  'long-sought-after': 94718,
#  'lunesta': 94717,
#  'lakers&lt': 94715,
#  '8-of-12': 94712,
#  'problems\\is': 94705,
#  'some\\of': 94701,
#  'as\\exporters': 94699,
#  'accounting\\standards': 94698,
#  'of\\housing': 94696,
#  'erbil': 94693,
#  'terroristscould': 94692,
#  'arebeing': 94691,
#  'solich': 94690,
#  'gawkers': 94687,
#  'komarnitsky': 94686,
#  'missileman': 94683,
#  'uppington': 94679,
#  'retorted': 95095,
#  'netball': 94678,
#  'leonie': 94676,
#  'lue': 94674,
#  'non-original': 94673,
#  'urinary': 94671,
#  'eighteen-hour': 94667,
#  'kodiak': 94663,
#  'aeneas': 94660,
#  'to\\set': 94656,
#  'october-december': 94655,
#  '19billion': 94652,
#  'consciously': 94647,
#  'a\\photograph': 94645,
#  'subliminal': 94644,
#  'linux-compatible': 94640,
#  'council\\changed': 94639,
#  '18-hour': 94638,
#  'police\\chief': 94636,
#  'be\\bluffing': 94635,
#  'a\\packed': 94634,
#  'orel': 94633,
#  'eyup': 94632,
#  '\\$aud': 94623,
#  'less-than-successful': 94617,
#  'orgeron': 94615,
#  'talkie': 94614,
#  'scented': 94608,
#  'lehr': 94607,
#  'diamondbacks\\have': 94601,
#  'wednesday\\placed': 94600,
#  '1861': 94597,
#  'malware-beleaguered': 94592,
#  'jcn': 94589,
#  'fired\\three': 94587,
#  'co-branding': 94583,
#  'iraq\\is': 94580,
#  '660-pound': 94574,
#  'billionths': 94573,
#  'an\\adaptor': 94570,
#  'wako': 94567,
#  'asimo': 94566,
#  'freeview': 94565,
#  'n10': 94562,
#  'pound7': 94560,
#  'e-backlash': 94559,
#  'trollaxor': 94557,
#  'vinigga': 94556,
#  'zeros': 94553,
#  'corpus-immobiliengruppe': 94552,
#  'whispered': 94551,
#  'general\\election': 94549,
#  'david\\blunkett': 94548,
#  '\\wanderers': 94547,
#  'poodle\\tag': 94546,
#  '2005\\but': 94545,
#  'showgoers': 94538,
#  'freeverse': 94537,
#  'macsoft': 94536,
#  'tuckaroo': 94534,
#  'when\\users': 94532,
#  'a\\trademark': 94531,
#  'wednesday\\handed': 94530,
#  'nuptial': 94529,
#  'dench': 94528,
#  'judi': 94527,
#  'seductively': 94526,
#  'ehlers': 94522,
#  'strong-dollar': 94521,
#  'mm&lt': 94519,
#  'mayor\\anthony': 94515,
#  'cinglar': 94513,
#  'airbuses': 94501,
#  'consummating': 94500,
#  'washington-nokia': 94499,
#  'walkie-talkie-like': 94498,
#  'conditioned': 94496,
#  'urther': 94494,
#  'lawuits': 94490,
#  '\\$35b': 94488,
#  'glamorgan': 94486,
#  'baseband': 94485,
#  'rml': 94483,
#  'unfrozen': 94482,
#  'timeshare': 94481,
#  'gerakas': 94478,
#  'bait-and-switch': 94471,
#  'pre-1923': 94469,
#  'karbala': 94468,
#  'einar': 94466,
#  'kommersant': 94465,
#  'the\\move': 94461,
#  'who\\earlier': 94459,
#  'peacetime': 94457,
#  'combats': 94452,
#  '15/12/04': 94451,
#  'andresen': 94450,
#  'scratch-off': 94444,
#  'wmg': 94443,
#  'mini-drama': 94441,
#  '414': 94440,
#  'reverse-engineering': 94438,
#  'illiquid': 94436,
#  'khler': 94435,
#  'access-point-on-a-chip': 94433,
#  'atheros': 94432,
#  '\\$35-billion': 94431,
#  'ticker=qlti': 94429,
#  'ticker=qlt': 94428,
#  'partzan': 94426,
#  'fine-particle': 94424,
#  'reginald': 94423,
#  'atoning': 94421,
#  '2-lehman': 94420,
#  'miandad': 94416,
#  'mckee': 94414,
#  'qaeda\\islamist': 94411,
#  'ticker=lm': 94409,
#  'transportacion': 94405,
#  'tfm': 94404,
#  'zafi-d': 94401,
#  'pooper': 94400,
#  '16-2004': 94396,
#  'the\\period': 94394,
#  'had\\arrested': 94391,
#  'lsass': 94386,
#  'carrots': 94383,
#  'staff\\several': 94378,
#  'overseas\\diplomatic': 94377,
#  'al-salam': 94375,
#  'super-jumbo': 94372,
#  'hoaxer': 94392,
#  'terrestial': 94368,
#  'caesarean': 94366,
#  '40-32': 94364,
#  'raised\\rates': 94359,
#  'basilea': 94355,
#  'sydney/jakarta': 94354,
#  'sinrod': 94350,
#  'kunar': 94349,
#  'kewal': 94346,
#  'croatians': 94345,
#  'recovey': 94344,
#  'its\\coastal': 94340,
#  'counter-proposal': 94339,
#  'd-1st': 94336,
#  'fptozdumb': 94329,
#  'small-minded': 94328,
#  'turnstile': 94326,
#  'worm_zafi': 94325,
#  'hijacked\\greek': 94322,
#  'sockers': 94318,
#  'hu-gol': 94316,
#  'francine': 94313,
#  'auberge': 94311,
#  'meatloaf-shaped': 94310,
#  'prepared\\to': 94309,
#  'land\\mammal': 94307,
#  'no\\easy': 94306,
#  'claris': 94302,
#  'elissa': 94301,
#  'minnesotas': 94300,
#  'displeased': 94299,
#  'leveller': 94293,
#  'verizon-sprint': 94292,
#  'grazer': 94289,
#  'militant\\gang': 94285,
#  'stipe': 94284,
#  'millionswednesday': 94283,
#  'luge': 94281,
#  't-6a': 94278,
#  'gastronomy': 94275,
#  'coauthored': 94272,
#  'goulston': 94269,
#  'hollydays': 94267,
#  '\\interest': 94261,
#  'per\\day': 94259,
#  'its\\opec': 94258,
#  '7-for-35': 94257,
#  'subramanium': 94254,
#  'westheimer': 94253,
#  'employer-paid': 94248,
#  'ex-mayor': 94246,
#  '66-yard': 94243,
#  'majerus': 94242,
#  'welders': 94241,
#  'data-sharing': 94239,
#  'frisked': 94238,
#  'but\\opponents': 94235,
#  'heavy\\consuming': 94230,
#  'cespedes': 94228,
#  '88-55': 94227,
#  'pitchforth': 94226,
#  'dix': 94214,
#  'palmars': 94213,
#  'auxsome': 94211,
#  'pennichuck': 95251,
#  'dragan': 94210,
#  'large-scale\\production': 94207,
#  'center\\for': 94206,
#  'orbit\\last': 94205,
#  'tweeden': 94204,
#  'leeann': 94203,
#  '63-52': 94202,
#  'eighth-graders': 94201,
#  'the\\nearly': 94200,
#  'the\\hollywood': 94197,
#  'push\\for': 94195,
#  'three\\afghan': 94193,
#  'first\\attempt': 94188,
#  'corporate\\sentiment': 94184,
#  'chord': 94173,
#  'aleida': 94165,
#  'informationgroup': 94162,
#  'networksreported': 94158,
#  'aita': 94155,
#  'still-very-low': 94154,
#  'seduced': 94150,
#  'ayurvedic': 94149,
#  'us-brokered': 94148,
#  'buds': 94147,
#  '\\$nz7': 94143,
#  'peoplesoftby': 94138,
#  'sea-side': 94136,
#  'goldfine': 94130,
#  'fortifying': 94129,
#  'discount\\retailer': 94128,
#  'mlbpa': 94121,
#  'warnedon': 94117,
#  'atr': 94113,
#  'schulman': 94111,
#  'a\\$89': 94110,
#  'repco': 94108,
#  'blockbuster-hollywood': 94107,
#  'reconfigure': 94106,
#  'gang-held': 94105,
#  '\\bank': 94103,
#  'a\\single': 94102,
#  'w32/zafi': 94100,
#  'mateen': 94096,
#  'bodleian': 94095,
#  'beloit': 94089,
#  'wep': 94088,
#  'bloggers\\\\well': 94086,
#  'hoshiarpur': 94085,
#  'simeone': 94083,
#  '1of': 94080,
#  'in\\meeting': 94074,
#  'chastised\\rich': 94073,
#  'there\\in': 94071,
#  'the\\melting': 94070,
#  'senor': 94062,
#  'trip\\to': 94059,
#  'e-christmas': 94057,
#  'appliance-based': 94052,
#  'waf': 94051,
#  'the\\injured': 94046,
#  'center\\jelani': 94045,
#  'dwarfing': 94044,
#  'tricolor': 94043,
#  'idly': 94040,
#  'cavendish': 94034,
#  'finepix': 94031,
#  'ticker=symc': 94029,
#  'kalle': 94025,
#  '\\30': 94021,
#  'moat': 94015,
#  'rigas\\family': 94013,
#  'awardas': 94011,
#  'conferring': 94010,
#  '51-hundred': 94009,
#  'zuhua': 94008,
#  '80-gbyte': 94005,
#  'ipod-class': 94004,
#  '\\$100m-share': 94002,
#  'tunable': 93992,
#  'xeroxinstitution': 93986,
#  'activation': 93985,
#  'edify': 93982,
#  'salesover': 93978,
#  'business\\intelligence': 93975,
#  'a\\dam': 93964,
#  'parliament\\of': 93963,
#  'uncompressed': 93962,
#  '10-bit': 93961,
#  'optibase': 93960,
#  'dassault\\systemes': 93959,
#  's\\unfinished': 93955,
#  'food\\program': 93953,
#  'needy-wfp': 93952,
#  'intefadeh': 93948,
#  'analysts\\had': 93945,
#  'has\\no': 93942,
#  'as\\sky-high': 93939,
#  '18-3': 94347,
#  'viaduct': 93937,
#  'pulsing': 93934,
#  'pulses': 93933,
#  'proquest': 93931,
#  'management-led': 93929,
#  'loftiest': 93926,
#  'tarn': 93923,
#  'ticker=vod': 93916,
#  '86b': 93914,
#  'reproaches': 93912,
#  'millau': 93910,
#  '1956-57': 93909,
#  'querying': 93906,
#  'baath': 93902,
#  'of\\kandahar': 93900,
#  'starve': 93896,
#  'megagiant': 93894,
#  'longitudinal': 93890,
#  '000-per-year': 93888,
#  'incurring': 93887,
#  'interceded': 93886,
#  'eel-like': 93884,
#  'to\\survive': 93883,
#  '\\refugee': 93882,
#  'disrupted\\aid': 93881,
#  '78-50': 93878,
#  'elysees\\and': 93874,
#  'singed': 93870,
#  '400-ton': 93869,
#  '80gb': 93860,
#  'backed\\demands': 93856,
#  'mcmurdo': 93855,
#  'peoplesoft/oracle': 93854,
#  'come-on': 93853,
#  'commercialise': 93850,
#  'perpendicular': 93849,
#  'fashioning': 93845,
#  'cost-cutters': 95797,
#  'maltese': 93842,
#  'nibs': 93840,
#  'ponderous': 93837,
#  'bolden': 93836,
#  '121-100': 93831,
#  'spectrasite': 93828,
#  'kidnapping\\in': 93826,
#  'drumstick': 93823,
#  'obsessive-compulsive': 93822,
#  'ridiculously': 93821,
#  'southside': 93819,
#  '104-101': 93817,
#  'nbonline': 93816,
#  'killed\\tuesday': 93812,
#  '200-square-yard': 93811,
#  'andrzej': 93808,
#  'lighted': 93806,
#  'underreported': 93805,
#  'nih': 93804,
#  'lowlights': 93802,
#  'be\\protected': 93798,
#  'mobi': 93797,
#  'periodicals': 93793,
#  'overreaction': 93792,
#  'back-and-': 93791,
#  'opposition\\leader': 93788,
#  'anchoring': 93786,
#  'dime-size': 93785,
#  'bunkley': 93784,
#  '3-way': 93783,
#  'morristown': 93782,
#  'virtual-wallet': 93779,
#  'water-linked': 93775,
#  'to\\digitally': 93774,
#  '148-member': 93769,
#  'taskbar': 93768,
#  '98-64': 93767,
#  'univaon': 93757,
#  'government-friendly': 93756,
#  '7-of-10': 93755,
#  'drive\\the': 93754,
#  'season-high\\40': 93753,
#  'transmission-based': 93752,
#  'salisberys': 93747,
#  'esapces': 93746,
#  '#6/5': 93745,
#  'palocci': 93743,
#  'prompt-paying': 93741,
#  'better-heeled': 93740,
#  'procures': 93739,
#  '\\$30-a-barrel': 93738,
#  'mozsource': 93736,
#  '106-83': 93735,
#  'top\\hollywood': 93730,
#  'the\\hit': 93729,
#  'mis-sold': 93728,
#  're\\$pect': 93726,
#  'forward\\eric': 95578,
#  '\\$642m': 93722,
#  'salted': 93720,
#  'snowbird': 93716,
#  'bunkered': 93713,
#  'uhnd': 93711,
#  'deactivated': 93708,
#  'movie\\legend': 93704,
#  'leader\\said': 93703,
#  'fractions': 93700,
#  'ucl': 93695,
#  'keefe\\resigned': 93692,
#  'to\\better-known': 93691,
#  '\\needs': 93690,
#  '71-60': 93687,
#  'band-aid': 93686,
#  'chemo': 93679,
#  'two\\thirds': 93672,
#  'war-report': 93671,
#  'chicago\\white': 93669,
#  'idiom': 93667,
#  'hipaa': 93665,
#  'itanium-powered': 95044,
#  'season--analysts': 93661,
#  'pcs--and': 93660,
#  'aimedat': 93659,
#  'penzias': 93656,
#  'arno': 93655,
#  '-nihk': 93645,
#  'logarithm': 93637,
#  'chessboard': 93636,
#  'cross-party': 93634,
#  'lyme': 93629,
#  'them\\the': 93627,
#  'for\\finding': 93626,
#  'poz': 93623,
#  'savings\\and': 93616,
#  'pape': 93607,
#  '2-late': 93606,
#  'unitedhealthcare': 93600,
#  '-juh': 93599,
#  'bunzl': 95296,
#  'fuh-loo': 93598,
#  'radars': 93597,
#  'markings': 93591,
#  'spiritualism': 93589,
#  '1-franklin': 93585,
#  'life-swapping': 93579,
#  'echr': 95327,
#  'with\\their': 93576,
#  'girardelli': 93574,
#  'newsmaker-shevchenko': 93573,
#  '77-67': 93572,
#  'suturing': 93567,
#  '20-plus': 93565,
#  'self-supporting': 93946,
#  'flyover': 93562,
#  'micosoft': 93557,
#  'in\\civil': 93555,
#  'company\\franklin': 93554,
#  'toronto-traded': 93553,
#  'unityone': 93552,
#  'xxxiv': 93549,
#  'nigeria-sudan': 93545,
#  'beijing-based': 93537,
#  'capitulated': 93536,
#  'tohead': 93534,
#  'formereuropean': 93533,
#  'heritage&lt': 93532,
#  'ex-eu': 93531,
#  'influentials/setting': 93527,
#  'sufferer': 93520,
#  'set-pieces': 93519,
#  'high\\street': 93518,
#  'rothchild': 93513,
#  '1-celtic': 93511,
#  'stjepan': 93509,
#  'bashed': 93508,
#  'lagerfelds': 93504,
#  'implacable': 93503,
#  'list\\with': 93499,
#  'homicide\\and': 93496,
#  'monday\\formally': 93494,
#  'iacovou': 93492,
#  'carlito': 93491,
#  'bayakoa': 93488,
#  'sedgars': 93487,
#  'fighting\\between': 93483,
#  'peoplesoftfor': 93477,
#  'against\\filing': 93475,
#  'tpti': 93473,
#  'ticker=tpti': 93472,
#  'ticker=bbdsvb': 93468,
#  'subcontract': 93466,
#  'mccaffrey': 93465,
#  'videoconference': 93461,
#  '200g': 93458,
#  '64-day': 93455,
#  'lak': 95410,
#  'west-central': 93454,
#  'big\\earthquakes': 93453,
#  'ampersand': 93445,
#  '\\$590': 93444,
#  'hybrid-vehicle': 93443,
#  '49ers/cardinals': 93441,
#  'precipice': 93437,
#  'short-': 93436,
#  'brse': 93432,
#  'anti-mubarak': 93429,
#  'carbondale': 93427,
#  'shipholding': 93421,
#  'baldinis': 93417,
#  'narcotic': 93413,
#  'pugilists': 93401,
#  '107-year-old': 93395,
#  '2003-based': 93393,
#  'snilsberg': 93392,
#  '230ft': 93390,
#  '70m-tall': 93389,
#  'washington-baltimore': 93385,
#  '5-foot-tall': 93383,
#  'global-markets-dollar': 93380,
#  'morse': 93379,
#  'cockler': 93378,
#  'burtonator': 93377,
#  '\\\\then': 93376,
#  'html\\document': 93375,
#  'just\\drag': 93373,
#  'its\\also': 93372,
#  'copy\\it': 93371,
#  '\\\\right': 93370,
#  'boupa': 93625,
#  'anise': 93368,
#  'coconut': 93367,
#  'glands': 93366,
#  'rose-tinted': 93365,
#  'red-walled': 93363,
#  'board\\has': 93362,
#  'weapons-technology': 93360,
#  'ivanov\\met': 93358,
#  'penalty-prone': 93357,
#  'briefed\\by': 93356,
#  'ricciardi': 93347,
#  'non-subscribers': 93345,
#  '798m': 93341,
#  ...}

# %%
stoi = vocab_.get_stoi()
stoi['.']
# Out:
# 2

# %%
vocab_.get_itos()
# Out:
# ['wall',
#  'st',
#  '.',
#  'bears',
#  'claw',
#  'back',
#  'into',
#  'the',
#  'black',
#  '(',
#  'reuters',
#  ')',
#  '-',
#  'short-sellers',
#  ',',
#  'street',
#  "'",
#  's',
#  'dwindling\\band',
#  'of',
#  'ultra-cynics',
#  'are',
#  'seeing',
#  'green',
#  'again',
#  'carlyle',
#  'looks',
#  'toward',
#  'commercial',
#  'aerospace',
#  'private',
#  'investment',
#  'firm',
#  'group',
#  '\\which',
#  'has',
#  'a',
#  'reputation',
#  'for',
#  'making',
#  'well-timed',
#  'and',
#  'occasionally\\controversial',
#  'plays',
#  'in',
#  'defense',
#  'industry',
#  'quietly',
#  'placed\\its',
#  'bets',
#  'on',
#  'another',
#  'part',
#  'market',
#  'oil',
#  'economy',
#  'cloud',
#  'stocks',
#  'outlook',
#  'soaring',
#  'crude',
#  'prices',
#  'plus',
#  'worries\\about',
#  'earnings',
#  'expected',
#  'to\\hang',
#  'over',
#  'stock',
#  'next',
#  'week',
#  'during',
#  'depth',
#  'the\\summer',
#  'doldrums',
#  'iraq',
#  'halts',
#  'exports',
#  'from',
#  'main',
#  'southern',
#  'pipeline',
#  'authorities',
#  'have',
#  'halted',
#  'export\\flows',
#  'after\\intelligence',
#  'showed',
#  'rebel',
#  'militia',
#  'could',
#  'strike\\infrastructure',
#  'an',
#  'official',
#  'said',
#  'saturday',
#  'soar',
#  'to',
#  'all-time',
#  'record',
#  'posing',
#  'new',
#  'menace',
#  'us',
#  'afp',
#  'tearaway',
#  'world',
#  'toppling',
#  'records',
#  'straining',
#  'wallets',
#  'present',
#  'economic',
#  'barely',
#  'three',
#  'months',
#  'before',
#  'presidential',
#  'elections',
#  'end',
#  'up',
#  'but',
#  'near',
#  'year',
#  'lows',
#  'ended',
#  'slightly',
#  'higher',
#  'friday\\but',
#  'stayed',
#  'as',
#  'surged',
#  'past',
#  '#36',
#  '46\\a',
#  'barrel',
#  'offsetting',
#  'positive',
#  'computer',
#  'maker\\dell',
#  'inc',
#  'dell',
#  'o',
#  'money',
#  'funds',
#  'fell',
#  'latest',
#  'ap',
#  'assets',
#  'nation',
#  'retail',
#  'mutual',
#  'by',
#  '1',
#  '17',
#  'billion',
#  '849',
#  '98',
#  'trillion',
#  'company',
#  'institute',
#  'thursday',
#  'fed',
#  'minutes',
#  'show',
#  'dissent',
#  'inflation',
#  'usatoday',
#  'com',
#  'sales',
#  'bounced',
#  'bit',
#  'july',
#  'claims',
#  'jobless',
#  'benefits',
#  'last',
#  'government',
#  'indicating',
#  'is',
#  'improving',
#  'midsummer',
#  'slump',
#  'safety',
#  'net',
#  'forbes',
#  'after',
#  'earning',
#  'ph',
#  'd',
#  'sociology',
#  'danny',
#  'bazil',
#  'riley',
#  'started',
#  'work',
#  'general',
#  'manager',
#  'at',
#  'real',
#  'estate',
#  'annual',
#  'base',
#  'salary',
#  '70',
#  '000',
#  'soon',
#  'financial',
#  'planner',
#  'stopped',
#  'his',
#  'desk',
#  'drop',
#  'off',
#  'brochures',
#  'about',
#  'insurance',
#  'available',
#  'through',
#  'employer',
#  '32',
#  'buying',
#  'was',
#  'furthest',
#  'thing',
#  'my',
#  'mind',
#  'says',
#  'york',
#  'dwindling',
#  'band',
#  'worries',
#  'hang',
#  'summer',
#  'no',
#  'need',
#  'opec',
#  'pump',
#  'more-iran',
#  'gov',
#  'tehran',
#  'can',
#  'do',
#  'nothing',
#  'douse',
#  'scorching',
#  'when',
#  'markets',
#  'already',
#  'oversupplied',
#  '2',
#  '8',
#  'million',
#  'barrels',
#  'per',
#  'day',
#  'bpd',
#  'iran',
#  'governor',
#  'warning',
#  'that',
#  'fall',
#  'sharply',
#  'non-opec',
#  'nations',
#  'should',
#  'output-purnomo',
#  'jakarta',
#  'exporters',
#  'consider',
#  'increasing',
#  'output',
#  'cool',
#  'president',
#  'purnomo',
#  'yusgiantoro',
#  'sunday',
#  'google',
#  'ipo',
#  'auction',
#  'rocky',
#  'start',
#  'washington/new',
#  'highly',
#  'anticipated',
#  'initial',
#  'public',
#  'offering',
#  'got',
#  'friday',
#  'web',
#  'search',
#  'sidestepped',
#  'bullet',
#  'u',
#  'securities',
#  'regulators',
#  'dollar',
#  'falls',
#  'broadly',
#  'trade',
#  'gap',
#  'tumbled',
#  'data',
#  'showing',
#  'deficit',
#  'june',
#  'cast',
#  'fresh',
#  'doubts',
#  'recovery',
#  'its',
#  'ability',
#  'draw',
#  'foreign',
#  'capital',
#  'fund',
#  'growing',
#  'rescuing',
#  'old',
#  'saver',
#  'if',
#  'you',
#  'think',
#  'may',
#  'help',
#  'your',
#  'elderly',
#  'relatives',
#  'with',
#  'their',
#  'finances',
#  'don',
#  't',
#  'be',
#  'shy',
#  'having',
#  'talk',
#  '--',
#  'kids',
#  'rule',
#  'back-to-school',
#  'purchasing',
#  'power',
#  'big',
#  'why',
#  'season',
#  'become',
#  'such',
#  'huge',
#  'marketing',
#  'phenomenon',
#  'down',
#  'head',
#  'value',
#  'there',
#  'little',
#  'cause',
#  'celebration',
#  'these',
#  'days',
#  'investors',
#  'value-focused',
#  'reason',
#  'feel',
#  'smug',
#  'only',
#  'because',
#  'they',
#  've',
#  'lost',
#  'less',
#  'than',
#  'folks',
#  'who',
#  'stuck',
#  'growth',
#  'swells',
#  'exploded',
#  '19',
#  '\\$55',
#  '8bn',
#  'costs',
#  'drove',
#  'imports',
#  'according',
#  'figures',
#  'shell',
#  'target',
#  'total',
#  'giant',
#  'bracing',
#  'itself',
#  'takeover',
#  'attempt',
#  'possibly',
#  'french',
#  'rival',
#  'press',
#  'report',
#  'faces',
#  'playboy',
#  'slip-up',
#  'bidding',
#  'gets',
#  'underway',
#  'despite',
#  'last-minute',
#  'interview',
#  'bosses',
#  'magazine',
#  'eurozone',
#  'keeps',
#  '12-nation',
#  'continues',
#  'grow',
#  'warnings',
#  'it',
#  'slow',
#  'later',
#  'expansion',
#  'slows',
#  'japan',
#  'country',
#  'experiences',
#  'domestic',
#  'corporate',
#  'spending',
#  'rand',
#  'shock',
#  'sa',
#  'rate',
#  'cut',
#  'interest',
#  'rates',
#  'trimmed',
#  '7',
#  '5',
#  'south',
#  'african',
#  'central',
#  'bank',
#  'lack',
#  'hits',
#  'surprises',
#  'car',
#  'across',
#  'board',
#  'cost',
#  'both',
#  'second',
#  'hand',
#  'cars',
#  'five',
#  'years',
#  'survey',
#  'found',
#  'korea',
#  'lowers',
#  'cuts',
#  'quarter',
#  'percentage',
#  'point',
#  '3',
#  'bid',
#  'drive',
#  'begins',
#  'shares',
#  'engine',
#  'which',
#  'floated',
#  'much',
#  '\\$36bn',
#  'takes',
#  'place',
#  'hp',
#  'tumble',
#  'profit',
#  'news',
#  'hewlett-packard',
#  'disappointing',
#  'third-quarter',
#  'profits',
#  'while',
#  'warns',
#  'final',
#  'will',
#  'also',
#  'short',
#  'expectations',
#  'mauritian',
#  'textile',
#  'jobs',
#  'one',
#  'oldest',
#  'operators',
#  'indian',
#  'ocean',
#  'island',
#  'mauritius',
#  'shut',
#  'seven',
#  'factories',
#  '900',
#  'chad',
#  'seeks',
#  'refugee',
#  'aid',
#  'imf',
#  'asks',
#  'loan',
#  'pay',
#  'looking',
#  'more',
#  '100',
#  'refugees',
#  'conflict-torn',
#  'darfur',
#  'western',
#  'sudan',
#  'nuclear',
#  'shuts',
#  'plants',
#  'running',
#  'japanese',
#  'plant',
#  'hit',
#  'fatal',
#  'accident',
#  'close',
#  'reactors',
#  'checks',
#  'veteran',
#  'inventor',
#  'float',
#  'trevor',
#  'baylis',
#  'famous',
#  'creating',
#  'freeplay',
#  'clockwork',
#  'radio',
#  'planning',
#  'saudi',
#  'arabia',
#  'open',
#  'taps',
#  'ready',
#  'push',
#  'extra',
#  'reverse',
#  'surging',
#  'phone',
#  'sector',
#  '\\$1bn',
#  'lift',
#  'led',
#  'uae',
#  'etisalat',
#  'plans',
#  'spend',
#  '544m',
#  'winning',
#  'two',
#  'mobile',
#  'licences',
#  'indians',
#  'fill',
#  'rail',
#  'skills',
#  'shortage',
#  'network',
#  'flies',
#  'specialist',
#  'engineers',
#  'west',
#  'coast',
#  'mainline',
#  'uk',
#  'steady',
#  'go',
#  'bedford',
#  'scientists',
#  'nitromed',
#  'hope',
#  'experimental',
#  'drugs',
#  'cure',
#  'heart',
#  'disease',
#  'someday',
#  'lately',
#  'focus',
#  'been',
#  'mundane',
#  'matters',
#  'type',
#  'confusing',
#  'secrecy',
#  'i',
#  'submitted',
#  'buy',
#  'auction-style',
#  'turn',
#  'out',
#  'good',
#  'or',
#  'bad',
#  'bargain',
#  'hunter',
#  'paradise',
#  'massachusetts',
#  'hunters',
#  'droves',
#  'shopped',
#  'hard',
#  'yesterday',
#  'tax',
#  'holiday',
#  'everything',
#  'treadmills',
#  'snow',
#  'blowers',
#  'candles',
#  'chandeliers',
#  'crediting',
#  '5-percent',
#  'break',
#  'bringing',
#  'them',
#  'stores',
#  'researchers',
#  'seek',
#  'untangle',
#  'e-mail',
#  'thread',
#  'victim',
#  'own',
#  'success',
#  'conclusion',
#  'ibm',
#  'corp',
#  'cambridge',
#  'spent',
#  'nearly',
#  'decade',
#  'conducting',
#  'field',
#  'tests',
#  'other',
#  'companies',
#  'how',
#  'employees',
#  'use',
#  'electronic',
#  'mail',
#  'clear',
#  'internet',
#  'killer',
#  'application',
#  'microsoft',
#  '0',
#  'kinder',
#  'culture',
#  'even',
#  'genius',
#  'mess',
#  'bill',
#  'gates',
#  'brilliant',
#  'technologist',
#  'he',
#  'cofounded',
#  'guided',
#  'greatness',
#  'size',
#  'historical',
#  'consequence',
#  'blundered',
#  'terrorized',
#  'underlings',
#  'temper',
#  'parceled',
#  'praise',
#  'like',
#  'scrooge',
#  'gave',
#  'charity',
#  'lash',
#  'inspired',
#  'necessary',
#  'aggressiveness',
#  'beat',
#  'competition',
#  'thought',
#  'letters',
#  'abusers',
#  'legal',
#  'weapons',
#  'we',
#  'all',
#  'share',
#  'outrage',
#  'expressed',
#  'columnist',
#  'steve',
#  'bailey',
#  'sizzler',
#  'quot',
#  'aug',
#  '11',
#  'killings',
#  'city',
#  'poor',
#  'neighborhoods',
#  'ignorance',
#  'argues',
#  'renewal',
#  'so-called',
#  'assault',
#  'weapon',
#  'ban',
#  'claiming',
#  'otherwise',
#  'uzis',
#  'ak-47s',
#  'flooding',
#  'streets',
#  'somewhere',
#  'between',
#  'gleam',
#  'gloom',
#  'bush',
#  'saying',
#  'turned',
#  'corner',
#  'democratic',
#  'candidate',
#  'senator',
#  'john',
#  'f',
#  'kerry',
#  'wake',
#  'this',
#  'month',
#  'quipped',
#  'u-turn',
#  'technology',
#  'sues',
#  'ex-employees',
#  'marlborough-based',
#  'suing',
#  'former',
#  'including',
#  'senior',
#  'managers',
#  'allegedly',
#  'conspiring',
#  'against',
#  'working',
#  'opening',
#  'competing',
#  'business',
#  'grant',
#  'lynn',
#  'square',
#  'brighter',
#  'sidewalks',
#  'curbs',
#  'fences',
#  'lights',
#  'landscaping',
#  'road',
#  'improvements',
#  'planned',
#  'gateway',
#  'artisan',
#  'block',
#  'key',
#  'area',
#  '\\$830',
#  'state',
#  'given',
#  'gives',
#  'salem',
#  '\\$10k',
#  'chapter',
#  '90',
#  'flameout',
#  'lawsuit',
#  'gary',
#  'winnick',
#  'chief',
#  'global',
#  'crossing',
#  'refocuses',
#  'attention',
#  'what',
#  'mr',
#  'knew',
#  'imploded',
#  'russia',
#  'superpower',
#  'flex',
#  'muscles',
#  '?',
#  'emerging',
#  'switching',
#  'titles',
#  'not',
#  'gears',
#  'kevin',
#  'b',
#  'rollins',
#  'executive',
#  'talks',
#  'transitory',
#  'slip',
#  'customer',
#  'service',
#  'sees',
#  'broader',
#  'taking',
#  'sale',
#  'ultimate',
#  'status',
#  'symbol',
#  'cash',
#  'rich',
#  'people',
#  'dying',
#  'wealth',
#  'stein',
#  'proposes',
#  'unique',
#  'solution',
#  'sell',
#  'nobility',
#  'quality',
#  'swept',
#  'away',
#  'distribution',
#  'hammered',
#  'reporting',
#  'large',
#  'loss',
#  'insurer',
#  'hurricane',
#  'charley',
#  'blows',
#  'house',
#  'make',
#  'delightful',
#  'results',
#  'grim',
#  'tech',
#  'just',
#  'isn',
#  'chrysler',
#  'bling',
#  'king',
#  'tough',
#  'detroit',
#  'troubled',
#  'carmaker',
#  'thanks',
#  'maverick',
#  'designer',
#  'dazzling',
#  'hip-hop',
#  'crowd',
#  'pool',
#  'hot',
#  'deck',
#  'americans',
#  'tricking',
#  'places',
#  'where',
#  'swim',
#  'here',
#  'look',
#  'wave',
#  'accessories',
#  'age',
#  'doom',
#  '1993',
#  'six',
#  'geeks',
#  'had',
#  'digital',
#  'nightmare',
#  'changed',
#  'get',
#  'far',
#  'creepier',
#  'hip',
#  'hop',
#  'online',
#  'shop',
#  'celebrity',
#  'fashion',
#  'booming',
#  'webpreneurs',
#  'stoking',
#  'steamroller',
#  'recording',
#  'artist',
#  'channel',
#  'american',
#  'middle-class',
#  'tastes',
#  'quite',
#  'chip',
#  'davis',
#  'best-selling',
#  'coming',
#  'rescue',
#  'problem',
#  'worry',
#  'find',
#  'every',
#  'specialized',
#  'customers',
#  'town',
#  'today',
#  'increasingly',
#  'demanding',
#  'asia',
#  'elsewhere',
#  'henry',
#  'astorga',
#  'describes',
#  'complex',
#  'reality',
#  'faced',
#  'marketers',
#  'includes',
#  'used',
#  'want',
#  'performance',
#  'now',
#  '!',
#  'monkeys',
#  '2004',
#  'edition',
#  'notes',
#  'philippine',
#  'well',
#  'election',
#  'time',
#  'republic',
#  'philippines',
#  'means',
#  'rolling',
#  'around',
#  'those',
#  'political',
#  'fun',
#  'laughing',
#  'heads',
#  'strange',
#  'goings-on',
#  'characterize',
#  'process',
#  'loosely',
#  'based',
#  'model',
#  'de',
#  'facto',
#  'fellini',
#  'movie',
#  'crossed',
#  'tom',
#  'jerry',
#  'cartoon',
#  'column',
#  'useful',
#  'election-year',
#  'glossary',
#  'oldsmobile',
#  'parking',
#  'lot',
#  'motors',
#  'dropped',
#  'four',
#  'brand',
#  'paradoxes',
#  'gm',
#  'face',
#  'name',
#  'product',
#  'image',
#  're-positioning',
#  'consumer',
#  'added',
#  'rebranding',
#  'belong',
#  'white',
#  'man',
#  'asian',
#  ...]

# %%
counter
# Out:
# Counter({'wall': 1395,
#          'st': 1409,
#          '.': 225971,
#          'bears': 399,
#          'claw': 17,
#          'back': 4123,
#          'into': 6637,
#          'the': 203843,
#          'black': 761,
#          '(': 41106,
#          'reuters': 19310,
#          ')': 40787,
#          '-': 39206,
#          'short-sellers': 2,
#          ',': 165685,
#          'street': 1581,
#          "'": 32235,
#          's': 61724,
#          'dwindling\\band': 1,
#          'of': 97909,
#          'ultra-cynics': 2,
#          'are': 9723,
#          'seeing': 135,
#          'green': 828,
#          'again': 1758,
#          'carlyle': 15,
#          'looks': 600,
#          'toward': 758,
#          'commercial': 490,
#          'aerospace': 124,
#          'private': 696,
#          'investment': 809,
#          'firm': 1776,
#          'group': 4676,
#          '\\which': 5,
#          'has': 18945,
#          'a': 110153,
#          'reputation': 117,
#          'for': 50186,
#          'making': 1114,
#          'well-timed': 2,
#          'and': 68872,
#          'occasionally\\controversial': 1,
#          'plays': 296,
#          'in': 95488,
#          'defense': 1192,
#          'industry': 2264,
#          'quietly': 140,
#          'placed\\its': 1,
#          'bets': 66,
#          'on': 56529,
#          'another': 2508,
#          'part': 1636,
#          'market': 3637,
#          'oil': 7225,
#          'economy': 1671,
#          'cloud': 112,
#          'stocks': 3127,
#          'outlook': 870,
#          'soaring': 259,
#          'crude': 1343,
#          'prices': 4880,
#          'plus': 306,
#          'worries\\about': 6,
#          'earnings': 2026,
#          'expected': 2266,
#          'to\\hang': 2,
#          'over': 11163,
#          'stock': 1907,
#          'next': 4165,
#          'week': 5250,
#          'during': 2393,
#          'depth': 50,
#          'the\\summer': 3,
#          'doldrums': 16,
#          'iraq': 6280,
#          'halts': 56,
#          'exports': 351,
#          'from': 17702,
#          'main': 714,
#          'southern': 1171,
#          'pipeline': 209,
#          'authorities': 770,
#          'have': 11128,
#          'halted': 100,
#          'export\\flows': 1,
#          'after\\intelligence': 1,
#          'showed': 909,
#          'rebel': 708,
#          'militia': 243,
#          'could': 4811,
#          'strike\\infrastructure': 1,
#          'an': 16845,
#          'official': 1912,
#          'said': 20007,
#          'saturday': 4005,
#          'soar': 120,
#          'to': 119205,
#          'all-time': 157,
#          'record': 3248,
#          'posing': 54,
#          'new': 21229,
#          'menace': 24,
#          'us': 12324,
#          'afp': 4524,
#          'tearaway': 1,
#          'world': 8465,
#          'toppling': 28,
#          'records': 369,
#          'straining': 20,
#          'wallets': 36,
#          'present': 157,
#          'economic': 1623,
#          'barely': 164,
#          'three': 4796,
#          'months': 1891,
#          'before': 2956,
#          'presidential': 1487,
#          'elections': 1161,
#          'end': 3118,
#          'up': 9710,
#          'but': 9083,
#          'near': 1646,
#          'year': 6235,
#          'lows': 274,
#          'ended': 818,
#          'slightly': 476,
#          'higher': 1993,
#          'friday\\but': 1,
#          'stayed': 118,
#          'as': 25176,
#          'surged': 272,
#          'past': 1651,
#          '#36': 1307,
#          '46\\a': 1,
#          'barrel': 894,
#          'offsetting': 22,
#          'positive': 396,
#          'computer': 2781,
#          'maker\\dell': 1,
#          'inc': 6830,
#          'dell': 762,
#          'o': 1593,
#          'money': 851,
#          'funds': 533,
#          'fell': 1368,
#          'latest': 1819,
#          'ap': 16152,
#          'assets': 359,
#          'nation': 1462,
#          'retail': 777,
#          'mutual': 292,
#          'by': 20733,
#          '1': 4292,
#          '17': 828,
#          'billion': 3381,
#          '849': 1,
#          '98': 41,
#          'trillion': 63,
#          'company': 7580,
#          'institute': 195,
#          'thursday': 7186,
#          'fed': 476,
#          'minutes': 518,
#          'show': 1214,
#          'dissent': 19,
#          'inflation': 453,
#          'usatoday': 286,
#          'com': 2877,
#          'sales': 3698,
#          'bounced': 77,
#          'bit': 240,
#          'july': 521,
#          'claims': 1106,
#          'jobless': 251,
#          'benefits': 381,
#          'last': 6315,
#          'government': 4673,
#          'indicating': 59,
#          'is': 22001,
#          'improving': 237,
#          'midsummer': 6,
#          'slump': 152,
#          'safety': 609,
#          'net': 1340,
#          'forbes': 235,
#          'after': 14394,
#          'earning': 41,
#          'ph': 2,
#          'd': 719,
#          'sociology': 1,
#          'danny': 107,
#          'bazil': 1,
#          'riley': 38,
#          'started': 498,
#          'work': 1569,
#          'general': 1719,
#          'manager': 1185,
#          'at': 24914,
#          'real': 1068,
#          'estate': 163,
#          'annual': 669,
#          'base': 431,
#          'salary': 102,
#          '70': 259,
#          '000': 3000,
#          'soon': 863,
#          'financial': 1441,
#          'planner': 12,
#          'stopped': 205,
#          'his': 14886,
#          'desk': 50,
#          'drop': 960,
#          'off': 4176,
#          'brochures': 1,
#          'about': 6356,
#          'insurance': 835,
#          'available': 641,
#          'through': 2156,
#          'employer': 40,
#          '32': 194,
#          'buying': 480,
#          'was': 13671,
#          'furthest': 3,
#          'thing': 332,
#          'my': 494,
#          'mind': 193,
#          'says': 5342,
#          'york': 6157,
#          'dwindling': 30,
#          'band': 174,
#          'worries': 505,
#          'hang': 78,
#          'summer': 532,
#          'no': 5786,
#          'need': 809,
#          'opec': 467,
#          'pump': 69,
#          'more-iran': 1,
#          'gov': 223,
#          'tehran': 373,
#          'can': 3750,
#          'do': 1412,
#          'nothing': 352,
#          'douse': 5,
#          'scorching': 11,
#          'when': 4986,
#          'markets': 884,
#          'already': 817,
#          'oversupplied': 1,
#          '2': 3776,
#          '8': 1360,
#          'million': 5499,
#          'barrels': 116,
#          'per': 1221,
#          'day': 3454,
#          'bpd': 26,
#          'iran': 1707,
#          'governor': 291,
#          'warning': 684,
#          'that': 27993,
#          'fall': 1406,
#          'sharply': 477,
#          'non-opec': 3,
#          'nations': 1451,
#          'should': 1506,
#          'output-purnomo': 1,
#          'jakarta': 348,
#          'exporters': 155,
#          'consider': 386,
#          'increasing': 251,
#          'output': 420,
#          'cool': 265,
#          'president': 5865,
#          'purnomo': 22,
#          'yusgiantoro': 21,
#          'sunday': 4887,
#          'google': 2538,
#          'ipo': 389,
#          'auction': 399,
#          'rocky': 76,
#          'start': 1930,
#          'washington/new': 3,
#          'highly': 199,
#          'anticipated': 196,
#          'initial': 466,
#          'public': 1536,
#          'offering': 882,
#          'got': 882,
#          'friday': 6754,
#          'web': 2384,
#          'search': 2787,
#          'sidestepped': 8,
#          'bullet': 36,
#          'u': 8278,
#          'securities': 633,
#          'regulators': 635,
#          'dollar': 2019,
#          'falls': 536,
#          'broadly': 42,
#          'trade': 2057,
#          'gap': 233,
#          'tumbled': 94,
#          'data': 2081,
#          'showing': 389,
#          'deficit': 511,
#          'june': 329,
#          'cast': 189,
#          'fresh': 655,
#          'doubts': 169,
#          'recovery': 421,
#          'its': 21925,
#          'ability': 236,
#          'draw': 519,
#          'foreign': 1499,
#          'capital': 1299,
#          'fund': 837,
#          'growing': 791,
#          'rescuing': 14,
#          'old': 887,
#          'saver': 14,
#          'if': 3056,
#          'you': 2980,
#          'think': 475,
#          'may': 4556,
#          'help': 2421,
#          'your': 1563,
#          'elderly': 68,
#          'relatives': 164,
#          'with': 26682,
#          'their': 10448,
#          'finances': 65,
#          'don': 782,
#          't': 5414,
#          'be': 11713,
#          'shy': 64,
#          'having': 533,
#          'talk': 508,
#          '--': 7951,
#          'kids': 150,
#          'rule': 469,
#          'back-to-school': 84,
#          'purchasing': 41,
#          'power': 1521,
#          'big': 2253,
#          'why': 549,
#          'season': 3869,
#          'become': 1053,
#          'such': 1123,
#          'huge': 536,
#          'marketing': 414,
#          'phenomenon': 27,
#          'down': 3428,
#          'head': 1615,
#          'value': 358,
#          'there': 2347,
#          'little': 1155,
#          'cause': 396,
#          'celebration': 107,
#          'these': 503,
#          'days': 1878,
#          'investors': 1632,
#          'value-focused': 1,
#          'reason': 279,
#          'feel': 209,
#          'smug': 4,
#          'only': 1950,
#          'because': 1866,
#          'they': 6414,
#          've': 418,
#          'lost': 1051,
#          'less': 897,
#          'than': 6221,
#          'folks': 73,
#          'who': 6059,
#          'stuck': 93,
#          'growth': 2167,
#          'swells': 10,
#          'exploded': 344,
#          '19': 727,
#          '\\$55': 145,
#          '8bn': 28,
#          'costs': 1177,
#          'drove': 229,
#          'imports': 191,
#          'according': 2463,
#          'figures': 429,
#          'shell': 199,
#          'target': 831,
#          'total': 487,
#          'giant': 2221,
#          'bracing': 35,
#          'itself': 405,
#          'takeover': 920,
#          'attempt': 639,
#          'possibly': 225,
#          'french': 1390,
#          'rival': 1303,
#          'press': 1751,
#          'report': 3176,
#          'faces': 685,
#          'playboy': 58,
#          'slip-up': 7,
#          'bidding': 128,
#          'gets': 1172,
#          'underway': 95,
#          'despite': 1680,
#          'last-minute': 91,
#          'interview': 354,
#          'bosses': 55,
#          'magazine': 298,
#          'eurozone': 91,
#          'keeps': 328,
#          '12-nation': 8,
#          'continues': 534,
#          'grow': 305,
#          'warnings': 213,
#          'it': 20338,
#          'slow': 500,
#          'later': 586,
#          'expansion': 373,
#          'slows': 110,
#          'japan': 2599,
#          'country': 2719,
#          'experiences': 37,
#          'domestic': 386,
#          'corporate': 836,
#          'spending': 803,
#          'rand': 31,
#          'shock': 266,
#          'sa': 167,
#          'rate': 982,
#          'cut': 2016,
#          'interest': 1083,
#          'rates': 1040,
#          'trimmed': 40,
#          '7': 1846,
#          '5': 2184,
#          'south': 2437,
#          'african': 818,
#          'central': 1125,
#          'bank': 2618,
#          'lack': 263,
#          'hits': 1019,
#          'surprises': 52,
#          'car': 1602,
#          'across': 1064,
#          'board': 1220,
#          'cost': 814,
#          'both': 1272,
#          'second': 3631,
#          'hand': 540,
#          'cars': 370,
#          'five': 2188,
#          'years': 4679,
#          'survey': 725,
#          'found': 1756,
#          'korea': 1424,
#          'lowers': 105,
#          'cuts': 1144,
#          'quarter': 2114,
#          'percentage': 96,
#          'point': 668,
#          '3': 2404,
#          'bid': 2368,
#          'drive': 738,
#          'begins': 440,
#          'shares': 2641,
#          'engine': 877,
#          'which': 4564,
#          'floated': 38,
#          'much': 1514,
#          '\\$36bn': 2,
#          'takes': 1169,
#          'place': 1085,
#          'hp': 593,
#          'tumble': 89,
#          'profit': 3118,
#          'news': 3424,
#          'hewlett-packard': 340,
#          'disappointing': 261,
#          'third-quarter': 1077,
#          'profits': 973,
#          'while': 2385,
#          'warns': 582,
#          'final': 2420,
#          'will': 14537,
#          'also': 1336,
#          'short': 679,
#          'expectations': 647,
#          'mauritian': 1,
#          'textile': 101,
#          'jobs': 1734,
#          'one': 7078,
#          'oldest': 88,
#          'operators': 182,
#          'indian': 907,
#          'ocean': 182,
#          'island': 635,
#          'mauritius': 2,
#          'shut': 311,
#          'seven': 1303,
#          'factories': 154,
#          '900': 92,
#          'chad': 153,
#          'seeks': 642,
#          'refugee': 253,
#          'aid': 970,
#          'imf': 175,
#          'asks': 264,
#          'loan': 161,
#          'pay': 1651,
#          'looking': 781,
#          'more': 9038,
#          '100': 858,
#          'refugees': 175,
#          'conflict-torn': 4,
#          'darfur': 1316,
#          'western': 778,
#          'sudan': 1168,
#          'nuclear': 1998,
#          'shuts': 75,
#          'plants': 207,
#          'running': 1059,
#          'japanese': 1270,
#          'plant': 492,
#          'hit': 2342,
#          'fatal': 93,
#          'accident': 185,
#          'close': 1440,
#          'reactors': 16,
#          'checks': 146,
#          'veteran': 309,
#          'inventor': 50,
#          'float': 73,
#          'trevor': 20,
#          'baylis': 1,
#          'famous': 177,
#          'creating': 232,
#          'freeplay': 1,
#          'clockwork': 2,
#          'radio': 918,
#          'planning': 431,
#          'saudi': 416,
#          'arabia': 209,
#          'open': 3155,
#          'taps': 83,
#          'ready': 894,
#          'push': 723,
#          'extra': 306,
#          'reverse': 79,
#          'surging': 138,
#          'phone': 1961,
#          'sector': 454,
#          '\\$1bn': 25,
#          'lift': 423,
#          'led': 968,
#          'uae': 47,
#          'etisalat': 3,
#          'plans': 3115,
#          'spend': 271,
#          '544m': 1,
#          'winning': 1048,
#          'two': 8926,
#          'mobile': 2244,
#          'licences': 16,
#          'indians': 218,
#          'fill': 126,
#          'rail': 96,
#          'skills': 91,
#          'shortage': 131,
#          'network': 2547,
#          'flies': 85,
#          'specialist': 86,
#          'engineers': 207,
#          'west': 1731,
#          'coast': 887,
#          'mainline': 4,
#          'uk': 1523,
#          'steady': 251,
#          'go': 1626,
#          'bedford': 13,
#          'scientists': 1343,
#          'nitromed': 5,
#          'hope': 709,
#          'experimental': 111,
#          'drugs': 625,
#          'cure': 48,
#          'heart': 776,
#          'disease': 318,
#          'someday': 35,
#          'lately': 54,
#          'focus': 702,
#          'been': 5503,
#          'mundane': 10,
#          'matters': 54,
#          'type': 120,
#          'confusing': 23,
#          'secrecy': 18,
#          'i': 1988,
#          'submitted': 70,
#          'buy': 2016,
#          'auction-style': 5,
#          'turn': 684,
#          'out': 7188,
#          'good': 1318,
#          'or': 3949,
#          'bad': 576,
#          'bargain': 74,
#          'hunter': 63,
#          'paradise': 32,
#          'massachusetts': 213,
#          'hunters': 85,
#          'droves': 5,
#          'shopped': 2,
#          'hard': 696,
#          'yesterday': 6095,
#          'tax': 1029,
#          'holiday': 761,
#          'everything': 237,
#          'treadmills': 3,
#          'snow': 207,
#          'blowers': 2,
#          'candles': 14,
#          'chandeliers': 2,
#          'crediting': 4,
#          '5-percent': 2,
#          'break': 536,
#          'bringing': 306,
#          'them': 2230,
#          'stores': 1012,
#          'researchers': 719,
#          'seek': 529,
#          'untangle': 7,
#          'e-mail': 924,
#          'thread': 14,
#          'victim': 156,
#          'own': 1061,
#          'success': 484,
#          'conclusion': 64,
#          'ibm': 2520,
#          'corp': 5138,
#          'cambridge': 76,
#          'spent': 382,
#          'nearly': 1499,
#          'decade': 353,
#          'conducting': 54,
#          'field': 1100,
#          'tests': 446,
#          'other': 3028,
#          'companies': 2423,
#          'how': 1643,
#          'employees': 623,
#          'use': 1543,
#          'electronic': 488,
#          'mail': 171,
#          'clear': 595,
#          'internet': 3888,
#          'killer': 140,
#          'application': 484,
#          'microsoft': 5842,
#          '0': 1019,
#          'kinder': 13,
#          'culture': 105,
#          'even': 1727,
#          'genius': 32,
#          'mess': 54,
#          'bill': 1270,
#          'gates': 346,
#          'brilliant': 53,
#          'technologist': 7,
#          'he': 8901,
#          'cofounded': 1,
#          'guided': 41,
#          'greatness': 17,
#          'size': 244,
#          'historical': 30,
#          'consequence': 11,
#          'blundered': 2,
#          'terrorized': 6,
#          'underlings': 2,
#          'temper': 15,
#          'parceled': 1,
#          'praise': 107,
#          'like': 1780,
#          'scrooge': 4,
#          'gave': 767,
#          'charity': 83,
#          'lash': 19,
#          'inspired': 79,
#          'necessary': 118,
#          'aggressiveness': 1,
#          'beat': 1577,
#          'competition': 803,
#          'thought': 466,
#          'letters': 57,
#          'abusers': 1,
#          'legal': 826,
#          'weapons': 754,
#          'we': 1235,
#          'all': 3555,
#          'share': 1447,
#          'outrage': 40,
#          'expressed': 234,
#          'columnist': 62,
#          'steve': 550,
#          'bailey': 28,
#          'sizzler': 1,
#          'quot': 9593,
#          'aug': 557,
#          '11': 1302,
#          'killings': 86,
#          'city': 3139,
#          'poor': 465,
#          'neighborhoods': 24,
#          'ignorance': 6,
#          'argues': 26,
#          'renewal': 24,
#          'so-called': 111,
#          'assault': 425,
#          'weapon': 87,
#          'ban': 750,
#          'claiming': 246,
#          'otherwise': 69,
#          'uzis': 3,
#          'ak-47s': 3,
#          'flooding': 103,
#          'streets': 240,
#          'somewhere': 40,
#          'between': 2344,
#          'gleam': 3,
#          'gloom': 40,
#          'bush': 3598,
#          'saying': 1051,
#          'turned': 567,
#          'corner': 108,
#          'democratic': 608,
#          'candidate': 448,
#          'senator': 135,
#          'john': 1991,
#          'f': 266,
#          'kerry': 1405,
#          'wake': 337,
#          'this': 8178,
#          'month': 2383,
#          'quipped': 3,
#          'u-turn': 17,
#          'technology': 2893,
#          'sues': 271,
#          'ex-employees': 2,
#          'marlborough-based': 1,
#          'suing': 107,
#          'former': 3363,
#          'including': 1715,
#          'senior': 955,
#          'managers': 342,
#          'allegedly': 279,
#          'conspiring': 31,
#          'against': 6839,
#          'working': 691,
#          'opening': 829,
#          'competing': 137,
#          'business': 3441,
#          'grant': 121,
#          'lynn': 39,
#          'square': 210,
#          'brighter': 34,
#          'sidewalks': 14,
#          'curbs': 55,
#          'fences': 16,
#          'lights': 103,
#          'landscaping': 4,
#          'road': 588,
#          'improvements': 87,
#          'planned': 658,
#          'gateway': 184,
#          'artisan': 36,
#          'block': 398,
#          'key': 1584,
#          'area': 653,
#          '\\$830': 3,
#          'state': 3593,
#          'given': 598,
#          'gives': 552,
#          'salem': 18,
#          '\\$10k': 1,
#          'chapter': 169,
#          '90': 171,
#          'flameout': 1,
#          'lawsuit': 654,
#          'gary': 252,
#          'winnick': 15,
#          'chief': 2934,
#          'global': 1783,
#          'crossing': 108,
#          'refocuses': 7,
#          'attention': 274,
#          'what': 2719,
#          'mr': 258,
#          'knew': 208,
#          'imploded': 4,
#          'russia': 1778,
#          'superpower': 10,
#          'flex': 44,
#          'muscles': 38,
#          '?': 5699,
#          'emerging': 193,
#          'switching': 60,
#          'titles': 183,
#          'not': 6967,
#          'gears': 39,
#          'kevin': 288,
#          'b': 284,
#          'rollins': 27,
#          'executive': 1755,
#          'talks': 2858,
#          'transitory': 2,
#          'slip': 225,
#          'customer': 311,
#          'service': 3042,
#          'sees': 745,
#          'broader': 85,
#          'taking': 1046,
#          'sale': 865,
#          'ultimate': 78,
#          'status': 255,
#          'symbol': 93,
#          'cash': 903,
#          'rich': 224,
#          'people': 4631,
#          'dying': 60,
#          'wealth': 82,
#          'stein': 9,
#          'proposes': 59,
#          'unique': 106,
#          'solution': 283,
#          'sell': 1117,
#          'nobility': 1,
#          'quality': 167,
#          'swept': 131,
#          'away': 1207,
#          'distribution': 186,
#          'hammered': 55,
#          'reporting': 248,
#          'large': 655,
#          'loss': 1906,
#          'insurer': 157,
#          'hurricane': 1261,
#          'charley': 193,
#          'blows': 78,
#          'house': 1379,
#          'make': 2534,
#          'delightful': 5,
#          'results': 1206,
#          'grim': 70,
#          'tech': 954,
#          'just': 2802,
#          'isn': 406,
#          'chrysler': 131,
#          'bling': 5,
#          'king': 483,
#          'tough': 498,
#          'detroit': 638,
#          'troubled': 405,
#          'carmaker': 86,
#          'thanks': 352,
#          'maverick': 34,
#          'designer': 79,
#          'dazzling': 28,
#          'hip-hop': 32,
#          'crowd': 330,
#          'pool': 154,
#          'hot': 405,
#          'deck': 30,
#          'americans': 843,
#          'tricking': 6,
#          'places': 153,
#          'where': 1512,
#          'swim': 26,
#          'here': 1301,
#          'look': 1039,
#          'wave': 275,
#          'accessories': 21,
#          'age': 296,
#          'doom': 53,
#          '1993': 32,
#          'six': 1623,
#          'geeks': 22,
#          'had': 5245,
#          'digital': 1352,
#          'nightmare': 101,
#          'changed': 310,
#          'get': 2385,
#          'far': 777,
#          'creepier': 2,
#          'hip': 83,
#          'hop': 7,
#          'online': 2762,
#          'shop': 130,
#          'celebrity': 49,
#          'fashion': 146,
#          'booming': 95,
#          'webpreneurs': 1,
#          'stoking': 21,
#          'steamroller': 6,
#          'recording': 249,
#          'artist': 42,
#          'channel': 239,
#          'american': 2803,
#          'middle-class': 15,
#          'tastes': 14,
#          'quite': 232,
#          'chip': 1172,
#          'davis': 703,
#          'best-selling': 60,
#          'coming': 754,
#          'rescue': 280,
#          'problem': 456,
#          'worry': 176,
#          'find': 861,
#          'every': 634,
#          'specialized': 21,
#          'customers': 1214,
#          'town': 645,
#          'today': 4687,
#          'increasingly': 259,
#          'demanding': 184,
#          'asia': 652,
#          'elsewhere': 110,
#          'henry': 186,
#          'astorga': 1,
#          'describes': 47,
#          'complex': 161,
#          'reality': 183,
#          'faced': 221,
#          'marketers': 20,
#          'includes': 294,
#          'used': 1337,
#          'want': 706,
#          'performance': 762,
#          'now': 2686,
#          '!': 846,
#          'monkeys': 31,
#          '2004': 3364,
#          'edition': 311,
#          'notes': 152,
#          'philippine': 171,
#          'well': 1085,
#          'election': 2248,
#          'time': 4659,
#          'republic': 350,
#          'philippines': 318,
#          'means': 251,
#          'rolling': 161,
#          'around': 1379,
#          'those': 910,
#          'political': 1168,
#          'fun': 135,
#          'laughing': 23,
#          'heads': 301,
#          'strange': 81,
#          'goings-on': 3,
#          'characterize': 1,
#          'process': 597,
#          'loosely': 8,
#          'based': 550,
#          'model': 306,
#          'de': 473,
#          'facto': 20,
#          'fellini': 2,
#          'movie': 478,
#          'crossed': 49,
#          'tom': 390,
#          'jerry': 98,
#          'cartoon': 25,
#          'column': 122,
#          'useful': 69,
#          'election-year': 25,
#          'glossary': 4,
#          'oldsmobile': 3,
#          'parking': 38,
#          'lot': 317,
#          'motors': 339,
#          'dropped': 481,
#          'four': 3002,
#          'brand': 239,
#          'paradoxes': 2,
#          'gm': 332,
#          'face': 1355,
#          'name': 676,
#          'product': 834,
#          'image': 392,
#          're-positioning': 1,
#          'consumer': 1291,
#          'added': 575,
#          'rebranding': 9,
#          'belong': 20,
#          'white': 918,
#          'man': 1713,
#          'asian': 680,
#          ...})

# %% [markdown]
# ## Building character vocabulary
#
# To build character-level generative network, we need to split text into individual characters instead of words. This can be done by defining a different tokenizer.  For example:
# - `vocab.stoi` - maps token strings in the vacab to a numeric identifier
# - `vocab.itos` - maps a number index from the vocab to a string

# %%
def char_tokenizer(words):
    return list(words) #[word for word in words]

counter = collections.Counter()
for (label, line) in train_dataset:
    counter.update(char_tokenizer(line))
vocab = torchtext.vocab.Vocab(counter)

vocab_size = len(vocab)
print(f"Vocabulary size = {vocab_size}")
print(f"Encoding of 'a' is {vocab.stoi['a']}")
print(f"Character with code 13 is {vocab.itos[13]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/q6/9w1dysg10bnbvq_ggcw1lsqh0000gn/T/ipykernel_2345/2554198823.py in <module>
#       2     return list(words) #[word for word in words]
#       3
# ----> 4 counter = collections.Counter()
#       5 for (label, line) in train_dataset:
#       6     counter.update(char_tokenizer(line))
#
# NameError: name 'collections' is not defined

# %% [markdown]
# Let's see the example of how we can encode the text from our dataset:

# %%
def enc(x):
    return torch.LongTensor(encode(x,voc=vocab,tokenizer=char_tokenizer))

print(f'sample text:\n{train_dataset[0][1]} ')
print(f'\nCharater encoding:\n{enc(train_dataset[0][1])} ')
# Out:
# sample text:
# Wall St. Bears Claw Back Into the Black (Reuters) Reuters - Short-sellers, Wall Street's dwindling\band of ultra-cynics, are seeing green again.
#
# Charater encoding:
# tensor([43,  4, 11, 11,  2, 26,  5, 23,  2, 38,  3,  4, 10,  9,  2, 31, 11,  4,
#         21,  2, 38,  4, 14, 25,  2, 34,  8,  5,  6,  2,  5, 13,  3,  2, 38, 11,
#          4, 14, 25,  2, 55, 37,  3, 15,  5,  3, 10,  9, 56,  2, 37,  3, 15,  5,
#          3, 10,  9,  2, 29,  2, 26, 13,  6, 10,  5, 29,  9,  3, 11, 11,  3, 10,
#          9, 27,  2, 43,  4, 11, 11,  2, 26,  5, 10,  3,  3,  5, 58,  9,  2, 12,
#         21,  7,  8, 12, 11,  7,  8, 18, 61, 22,  4,  8, 12,  2,  6, 19,  2, 15,
#         11,  5, 10,  4, 29, 14, 20,  8,  7, 14,  9, 27,  2,  4, 10,  3,  2,  9,
#          3,  3,  7,  8, 18,  2, 18, 10,  3,  3,  8,  2,  4, 18,  4,  7,  8, 23])

# %% [markdown]
# ## Training a generative RNN
#
# The way we will train RNN to generate text is the following. On each step, we will take a sequence of characters of length `nchars`, and ask the network to generate the next output character for each input character:
#
# <img alt="Image showing an example RNN generation of the word 'HELLO'." src="images/6-generative-networks-2.png" align="middle" />
#
# Depending on the actual scenario, we may also want to include some special characters, such as *end-of-sequence* `<eos>`. In our case, we just want to train the network for endless text generation, thus we will fix the size of each sequence to be equal to `nchars` tokens. Consequently, each training example will consist of `nchars` inputs and `nchars` outputs (which are input sequence shifted one symbol to the left). Minibatch will consist of several such sequences.
#
# The way we will generate minibatches is to take each news text of length `l`, and generate all possible input-output combinations from it (there will be `l-nchars` such combinations). They will form one minibatch, and size of minibatches would be different at each training step.

# %%
nchars = 100

def get_batch(s,nchars=nchars):
    ins = torch.zeros(len(s)-nchars,nchars,dtype=torch.long,device=device)
    outs = torch.zeros(len(s)-nchars,nchars,dtype=torch.long,device=device)
    for i in range(len(s)-nchars):
        ins[i] = enc(s[i:i+nchars])
        outs[i] = enc(s[i+1:i+nchars+1])
    return ins,outs

get_batch(train_dataset[0][1])
# Out:
# (tensor([[43,  4, 11,  ..., 18, 61, 22],
#          [ 4, 11, 11,  ..., 61, 22,  4],
#          [11, 11,  2,  ..., 22,  4,  8],
#          ...,
#          [37,  3, 15,  ...,  4, 18,  4],
#          [ 3, 15,  5,  ..., 18,  4,  7],
#          [15,  5,  3,  ...,  4,  7,  8]]),
#  tensor([[ 4, 11, 11,  ..., 61, 22,  4],
#          [11, 11,  2,  ..., 22,  4,  8],
#          [11,  2, 26,  ...,  4,  8, 12],
#          ...,
#          [ 3, 15,  5,  ..., 18,  4,  7],
#          [15,  5,  3,  ...,  4,  7,  8],
#          [ 5,  3, 10,  ...,  7,  8, 23]]))

# %% [markdown]
# Now let's define the generative network. It can be based on any recurrent cell which we discussed in the previous unit (simple, LSTM or GRU). In our example we will use LSTM.
#
# Because the network takes characters as input, and vocabulary size is pretty small, we do not need embedding layer, one-hot-encoded input can directly go to LSTM cell. However, because we pass character numbers as input, we need to one-hot-encode them before passing to LSTM. This is done by calling `one_hot` function during `forward` pass. Output encoder would be a linear layer that will convert hidden state into one-hot-encoded output.

# %%
class LSTMGenerator(torch.nn.Module):
    def __init__(self, vocab_size, hidden_dim):
        super().__init__()
        self.rnn = torch.nn.LSTM(vocab_size,hidden_dim,batch_first=True)
        self.fc = torch.nn.Linear(hidden_dim, vocab_size)

    def forward(self, x, s=None):
        x = torch.nn.functional.one_hot(x,vocab_size).to(torch.float32)
        x,s = self.rnn(x,s)
        return self.fc(x),s

# %% [markdown]
# During training, we want to be able to sample generated text. To do that, we will define a `generate` function that will produce an output string of length `size`, starting from the initial string `start`.
#
# The way it works is the following:
# - First, we will pass the whole start string through the network, and take output state `s`
# and next predicted character `out`.
# - Since `out` is one-hot encoded, we take `argmax` to get the index of the character `nc` in the vocabulary, and use `itos` to figure out the actual character and append it to the resulting list of characters `chars`.
# - This process of generating one character is repeated `size` times to generate required number of characters.

# %%
def generate(net,size=100,start='today '):
        chars = list(start)
        out, s = net(enc(chars).view(1,-1).to(device))
        for i in range(size):
            nc = torch.argmax(out[0][-1])
            chars.append(vocab.itos[nc])
            out, s = net(nc.view(1,-1),s)
        return ''.join(chars)

# %% [markdown]
# Now let's do the training! The training loop is almost the same as in all our previous examples, but instead of accuracy we print sampled generated text every 1000 epochs.
#
# Special attention needs to be paid to the way we compute loss. We need to compute loss given one-hot-encoded output `out`, and expected text `text_out`, which is the list of character indices. Luckily, the `cross_entropy` function expects unnormalized network output as first argument, and class number as the second, which is exactly what we have. It also performs automatic averaging over minibatch size.
#
# We also limit the training by `samples_to_train` samples, in order not to wait for too long. We encourage you to experiment and try longer training, possibly for several epochs (in which case you would need to create another loop around this code).

# %%
net = LSTMGenerator(vocab_size,64).to(device)

samples_to_train = 10000
optimizer = torch.optim.Adam(net.parameters(),0.01)
loss_fn = torch.nn.CrossEntropyLoss()
net.train()
for i,x in enumerate(train_dataset):
    # x[0] is class label, x[1] is text
    if len(x[1])-nchars<10:
        continue
    samples_to_train-=1
    if not samples_to_train: break
    text_in, text_out = get_batch(x[1])
    optimizer.zero_grad()
    out,s = net(text_in)
    loss = torch.nn.functional.cross_entropy(out.view(-1,vocab_size),text_out.flatten()) #cross_entropy(out,labels)
    loss.backward()
    optimizer.step()
    if i%1000==0:
        print(f"Current loss = {loss.item()}")
        print(generate(net))
# Out:
# Current loss = 4.4620537757873535
# today hhllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllll
# Current loss = 2.118957281112671
# today and and and and and and and and and and and and and and and and and and and and and and and and and
# Current loss = 1.6416268348693848
# today and the company to a the company to a the company to a the company to a the company to a the company
# Current loss = 2.464548110961914
# today and a the US the product to the US the product to the US the product to the US the product to the US
# Current loss = 1.7117735147476196
# today and the state the state the state the state the state the state the state the state the state the st
# Current loss = 1.667232632637024
# today a second the company and the company and the company and the company and the company and the company
# Current loss = 1.9207301139831543
# today a first the first the first the first the first the first the first the first the first the first th
# Current loss = 1.8068740367889404
# today a second and a second and a second and a second and a second and a second and a second and a second
# Current loss = 1.6818790435791016
# today and and and and and and and and and and and and and and and and and and and and and and and and and
# Current loss = 1.4428272247314453
# today and the said the some the said the some the said the some the said the some the said the some the sa
# Current loss = 1.5722841024398804
# today that the second to the second to the second to the second to the second to the second to the second

# %% [markdown]
# This example already generates some pretty good text, but it can be further improved in several ways:
# * **Better minibatch generation**. The way we prepared data for training was to generate one minibatch from one sample. This is not ideal, because minibatches are all of different sizes, and some of them even cannot be generated, because the text is smaller than `nchars`. Also, small minibatches do not load GPU sufficiently enough. It would be wiser to get one large chunk of text from all samples, then generate all input-output pairs, shuffle them, and generate minibatches of equal size.
# * **Multilayer LSTM**. It makes sense to try 2 or 3 layers of LSTM cells. As we mentioned in the previous unit, each layer of LSTM extracts certain patterns from text, and in case of character-level generator we can expect lower LSTM level to be responsible for extracting syllables, and higher levels - for words and word combinations. This can be simply implemented by passing number-of-layers parameter to LSTM constructor.
# * You may also want to experiment with **GRU units** and see which ones perform better, and with **different hidden layer sizes**. Too large hidden layer may result in overfitting (e.g. network will learn exact text), and smaller size might not produce good result.

# %% [markdown]
# ## Soft text generation and temperature
#
# In the previous definition of `generate`, we were always taking the character with highest probability as the next character in generated text. This resulted in the fact that the text often "cycled" between the same character sequences again and again, like in this example:
# ```
# today of the second the company and a second the company ...
# ```
#
# However, if we look at the probability distribution for the next character, it could be that the difference between a few highest probabilities is not huge, e.g. one character can have probability 0.2, another - 0.19, etc. For example, when looking for the next character in the sequence '*play*', next character can equally well be either space, or **e** (as in the word *player*).
#
# This leads us to the conclusion that it is not always "fair" to select the character with higher probability, because choosing the second highest might still lead us to meaningful text. It is more wise to **sample** characters from the probability distribution given by the network output.
#
# This sampling can be done using `multinomial` function that implements so-called **multinomial distribution**. A function that implements this **soft** text generation is defined below:

# %%
def generate_soft(net,size=100,start='today ',temperature=1.0):
        chars = list(start)
        out, s = net(enc(chars).view(1,-1).to(device))
        for i in range(size):
            #nc = torch.argmax(out[0][-1])
            out_dist = out[0][-1].div(temperature).exp()
            nc = torch.multinomial(out_dist,1)[0]
            chars.append(vocab.itos[nc])
            out, s = net(nc.view(1,-1),s)
        return ''.join(chars)
    
for i in [0.3,0.8,1.0,1.3,1.8]:
    print(f"--- Temperature = {i}\n{generate_soft(net,size=300,start='Today ',temperature=i)}\n")
# Out:
# --- Temperature = 0.3
# Today and to has a software to in the first the power the gold medal was of the first and succer to the company will a report the first the and the gain the company in the and a new a report a pack of the four the first the company of the such with the half to a security to the and a success the first she
#
# --- Temperature = 0.8
# Today drud out of the three-rent possiem that sales purssion has finminiaty women's from NAC Inc. (AP) -- Shimbon has weel with a may stelight first three flaw gold from their a scent, big study with a nighting sovicturner has slarh football at a hour of Angelage discression, into cubs, US year player sor
#
# --- Temperature = 1.0
# Today by compoy, said to hup the couns ay rrope iist\fill sinie-5-1- than he of a fightier Corp. the Vew, Mkli Unite Hold Austria on Tuesday resfare rextarted in the new has buy thisnillials thrust first capuration of the it larget expected the ir edulagy Airin Penny after Emonet Cuc Washieve an are Gurry
#
# --- Temperature = 1.3
# Today cluscy,, wangled and-ox they, stee of as;\seculity dillancrile inmution svanse gall ATHEYS today a first oresift 6-Jalf mangback explymate that wrook" haffic illowbre overwage in Tecrian Hunrieleers to attowny service Adching, blanks governine? Aug. : : NE: Sir NFP (P2AAU) Bow SWDE: The ex2"cut Pmoc
#
# --- Temperature = 1.8
# Today sas gom, twing hWe a Dajfcou hamb--5 to bemolecresem ig irkembets plentll repws, scatchey: Actuss.io Theffouge, cirw biggemed Goiga propperinut you racive #5-Aeia:riato..Lf. N7TNap:,ser,wploy a Fraull tbashonerdlantuanseve /bBT -$06 Wemob-e.P EvVlaicy), ZOf0 cUSeballd sturk out houselty, TARZM) AbAe

# %% [markdown]
# We have introduced one more parameter called **temperature**, which is used to indicate how hard we should stick to the highest probability. If temperature is 1.0, we do fair multinomial sampling, and when temperature goes to infinity - all probabilities become equal, and we randomly select next character. In the example below we can observe that the text becomes meaningless when we increase the temperature too much, and it resembles "cycled" hard-generated text when it becomes closer to 0.
